# %% [markdown]
# # Title

# %% [markdown]
# ## Introduction

# %% [markdown]
# Our question is: Can age and experience predict whether or not a player is subscribed to a game-related newsletter in the players.csv dataset?

# %% [markdown]
# ## Methods

# %%
#Run these beforehand
library(tidyverse)
library(repr)
library(tidymodels)
library(ggplot2)
library(gridExtra)

# %%
#Loading and cleaning dataset
players <- read_csv("players.csv")
colnames(players) <- c("experience","subscribe", "hashed_email", "played_hours", "name", "gender", "age")
players <- players |> 
    filter(!is.na(age)) |>
    filter(!is.na(experience))
players$experience

# %%
players$experience_numeric <- recode(df$experience, 
                          "A" = 4, 
                          "B" = 3, 
                          "C" = 2, 
                          "D" = 1, 
                          "F" = 0)

# %% [markdown]
# ## Results

# %% [markdown]
# ## Discussion
